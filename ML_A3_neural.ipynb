# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 0             1    15634602   Hargrave  ...               1       101348.88      1
# 1             2    15647311       Hill  ...               1       112542.58      0
# 2             3    15619304       Onio  ...               0       113931.57      1
# 3             4    15701354       Boni  ...               0        93826.63      0
# 4             5    15737888   Mitchell  ...               1        79084.10      0
# ...         ...         ...        ...  ...             ...             ...    ...
# 9995       9996    15606229   Obijiaku  ...               0        96270.64      0
# 9996       9997    15569892  Johnstone  ...               1       101699.77      0
# 9997       9998    15584532        Liu  ...               1        42085.58      1
# 9998       9999    15682355  Sabbatini  ...               0        92888.52      1
# 9999      10000    15628319     Walker  ...               0        38190.78      0
#
# [10000 rows x 14 columns]

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  ... HasCrCard IsActiveMember  EstimatedSalary  Exited
# 0          1    15634602  Hargrave          619  ...         1              1        101348.88       1
# 1          2    15647311      Hill          608  ...         0              1        112542.58       0
# 2          3    15619304      Onio          502  ...         1              0        113931.57       1
# 3          4    15701354      Boni          699  ...         0              0         93826.63       0
# 4          5    15737888  Mitchell          850  ...         1              1         79084.10       0
#
# [5 rows x 14 columns]

# %%
df.tail(5)
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 9995       9996    15606229   Obijiaku  ...               0        96270.64      0
# 9996       9997    15569892  Johnstone  ...               1       101699.77      0
# 9997       9998    15584532        Liu  ...               1        42085.58      1
# 9998       9999    15682355  Sabbatini  ...               0        92888.52      1
# 9999      10000    15628319     Walker  ...               0        38190.78      0
#
# [5 rows x 14 columns]

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore  ...  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000  1.000000e+04  10000.000000  ...    10000.000000     10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800  ...        0.515100    100090.239881      0.203700
# std     2886.89568  7.193619e+04     96.653299  ...        0.499797     57510.492818      0.402769
# min        1.00000  1.556570e+07    350.000000  ...        0.000000        11.580000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000  ...        0.000000     51002.110000      0.000000
# 50%     5000.50000  1.569074e+07    652.000000  ...        1.000000    100193.915000      0.000000
# 75%     7500.25000  1.575323e+07    718.000000  ...        1.000000    149388.247500      0.000000
# max    10000.00000  1.581569e+07    850.000000  ...        1.000000    199992.480000      1.000000
#
# [8 rows x 11 columns]

# %%
df.size
# Out:
# 140000

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.drop(columns = ["RowNumber","CustomerId","Surname"],inplace = True)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  ...  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             619    France  Female   42  ...          1               1        101348.88       1
# 1             608     Spain  Female   41  ...          0               1        112542.58       0
# 2             502    France  Female   42  ...          1               0        113931.57       1
# 3             699    France  Female   39  ...          0               0         93826.63       0
# 4             850     Spain  Female   43  ...          1               1         79084.10       0
# ...           ...       ...     ...  ...  ...        ...             ...              ...     ...
# 9995          771    France    Male   39  ...          1               0         96270.64       0
# 9996          516    France    Male   35  ...          1               1        101699.77       0
# 9997          709    France  Female   36  ...          0               1         42085.58       1
# 9998          772   Germany    Male   42  ...          1               0         92888.52       1
# 9999          792    France  Female   28  ...          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
plt.figure(figsize=(8,8))
sns.countplot(x = 'Exited',data = df)
plt.title("Count Plot")
plt.xlabel('0: Customers still with the bank,1:Customers exited the bank')
plt.ylabel('count')
plt.show()

# %%
df.isnull().any()
# Out:
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  ...  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             619    France  Female   42  ...          1               1        101348.88       1
# 1             608     Spain  Female   41  ...          0               1        112542.58       0
# 2             502    France  Female   42  ...          1               0        113931.57       1
# 3             699    France  Female   39  ...          0               0         93826.63       0
# 4             850     Spain  Female   43  ...          1               1         79084.10       0
# ...           ...       ...     ...  ...  ...        ...             ...              ...     ...
# 9995          771    France    Male   39  ...          1               0         96270.64       0
# 9996          516    France    Male   35  ...          1               1        101699.77       0
# 9997          709    France  Female   36  ...          0               1         42085.58       1
# 9998          772   Germany    Male   42  ...          1               0         92888.52       1
# 9999          792    France  Female   28  ...          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
geography = pd.get_dummies(df['Geography'])

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
gender = pd.get_dummies(df['Gender'])

# %%
df = pd.concat([df,geography,gender],axis = 1)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure  ...  France  Germany  Spain  Female  Male
# 0             619    France  Female   42       2  ...       1        0      0       1     0
# 1             608     Spain  Female   41       1  ...       0        0      1       1     0
# 2             502    France  Female   42       8  ...       1        0      0       1     0
# 3             699    France  Female   39       1  ...       1        0      0       1     0
# 4             850     Spain  Female   43       2  ...       0        0      1       1     0
# ...           ...       ...     ...  ...     ...  ...     ...      ...    ...     ...   ...
# 9995          771    France    Male   39       5  ...       1        0      0       0     1
# 9996          516    France    Male   35      10  ...       1        0      0       0     1
# 9997          709    France  Female   36       7  ...       1        0      0       1     0
# 9998          772   Germany    Male   42       3  ...       0        1      0       0     1
# 9999          792    France  Female   28       4  ...       1        0      0       1     0
#
# [10000 rows x 16 columns]

# %%
df.drop(columns = ['Geography','Gender'],inplace = True)

# %%
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  ...  France  Germany  Spain  Female  Male
# 0             619   42       2       0.00              1  ...       1        0      0       1     0
# 1             608   41       1   83807.86              1  ...       0        0      1       1     0
# 2             502   42       8  159660.80              3  ...       1        0      0       1     0
# 3             699   39       1       0.00              2  ...       1        0      0       1     0
# 4             850   43       2  125510.82              1  ...       0        0      1       1     0
# ...           ...  ...     ...        ...            ...  ...     ...      ...    ...     ...   ...
# 9995          771   39       5       0.00              2  ...       1        0      0       0     1
# 9996          516   35      10   57369.61              1  ...       1        0      0       0     1
# 9997          709   36       7       0.00              1  ...       1        0      0       1     0
# 9998          772   42       3   75075.31              2  ...       0        1      0       0     1
# 9999          792   28       4  130142.79              1  ...       1        0      0       1     0
#
# [10000 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('Exited',axis = 1)
y = df['Exited']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20,random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units = 6,kernel_initializer='he_uniform',activation = 'relu',input_dim = 13))

# %%
classifier.add(Dense(units = 6,kernel_initializer='he_uniform',activation = 'relu'))

# %%
classifier.add(Dense(units = 1,kernel_initializer='glorot_uniform',activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'adam',loss = 'binary_crossentropy',metrics = ['accuracy'])

# %%
model_history = classifier.fit(x_train,y_train,batch_size = 10,epochs = 100,validation_split = 0.33)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 3s 4ms/step - loss: 0.4999 - accuracy: 0.7957 - val_loss: 0.4702 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4584 - accuracy: 0.7962 - val_loss: 0.4539 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4459 - accuracy: 0.7962 - val_loss: 0.4459 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4380 - accuracy: 0
# Epoch 74/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3261 - accuracy: 0.8636 - val_loss: 0.3626 - val_accuracy: 0.8531
# Epoch 75/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3249 - accuracy: 0.8673 - val_loss: 0.3596 - val_accuracy: 0.8546
# Epoch 76/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3245 - accuracy: 0.8670 - val_loss: 0.3636 - val_accuracy: 0.8516
# Epoch 77/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3259 - accuracy: 0.8658 - val_loss: 0.3634 - val_accuracy: 0.8516
# Epoch 78/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3242 - accuracy: 0.8673 - val_loss: 0.3684 - val_accuracy: 0.8501
# Epoch 79/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3249 - accuracy: 0.8642 - val_loss: 0.3646 - val_accuracy: 0.8504
# Epoch 80/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3246 - accuracy: 0.8662 - val_loss: 0.3662 - val_accuracy: 0.8535
# Epoch 81/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3252 - accuracy: 0.8670 - val_loss: 0.3621 - val_accuracy: 0.8542
# Epoch 82/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3251 - accuracy: 0.8666 - val_loss: 0.3644 - val_accuracy: 0.8523
# Epoch 83/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3243 - accuracy: 0.8666 - val_loss: 0.3675 - val_accuracy: 0.8493
# Epoch 84/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3246 - accuracy: 0.8643 - val_loss: 0.3613 - val_accuracy: 0.8557
# Epoch 85/100
# 536/536 [==============================] - 5s 9ms/step - loss: 0.3258 - accuracy: 0.8668 - val_loss: 0.3623 - val_accuracy: 0.8531
# Epoch 86/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3233 - accuracy: 0.8670 - val_loss: 0.3619 - val_accuracy: 0.8538
# Epoch 87/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3239 - accuracy: 0.8655 - val_loss: 0.3723 - val_accuracy: 0.8402
# Epoch 88/100
# 536/536 [==============================] - 4s 8ms/step - loss: 0.3250 - accuracy: 0.8660 - val_loss: 0.3626 - val_accuracy: 0.8519
# Epoch 89/100
# 536/536 [==============================] - 5s 10ms/step - loss: 0.3242 - accuracy: 0.8668 - val_loss: 0.3622 - val_accuracy: 0.8557
# Epoch 90/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3237 - accuracy: 0.8647 - val_loss: 0.3612 - val_accuracy: 0.8542
# Epoch 91/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3244 - accuracy: 0.8679 - val_loss: 0.3598 - val_accuracy: 0.8546
# Epoch 92/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3230 - accuracy: 0.8709 - val_loss: 0.3647 - val_accuracy: 0.8508
# Epoch 93/100
# 536/536 [==============================] - 4s 7ms/step - loss: 0.3237 - accuracy: 0.8683 - val_loss: 0.3649 - val_accuracy: 0.8531
# Epoch 94/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3246 - accuracy: 0.8655 - val_loss: 0.3627 - val_accuracy: 0.8497
# Epoch 95/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3241 - accuracy: 0.8636 - val_loss: 0.3623 - val_accuracy: 0.8535
# Epoch 96/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3234 - accuracy: 0.8681 - val_loss: 0.3634 - val_accuracy: 0.8482
# Epoch 97/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3234 - accuracy: 0.8668 - val_loss: 0.3594 - val_accuracy: 0.8561
# Epoch 98/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3238 - accuracy: 0.8686 - val_loss: 0.3667 - val_accuracy: 0.8482
# Epoch 99/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3241 - accuracy: 0.8670 - val_loss: 0.3645 - val_accuracy: 0.8485
# Epoch 100/100
# 536/536 [==============================] - 4s 8ms/step - loss: 0.3229 - accuracy: 0.8671 - val_loss: 0.3659 - val_accuracy: 0.8527

# %%
plt.figure(figsize = (8,8))
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.figure(figsize = (8,8))
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# 63/63 [==============================] - 0s 1ms/step
# array([[0.33555654],
#        [0.3033773 ],
#        [0.11068614],
#        ...,
#        [0.14333893],
#        [0.22034645],
#        [0.3195136 ]], dtype=float32)

# %%
y_pred = y_pred > 0.5
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import accuracy_score
asco=accuracy_score(y_test,y_pred)
asco
# Out:
# 0.86
